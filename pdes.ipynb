# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from pdes import *

# %%
N = 20
x = np.linspace(0,1,N+2)
u = solve_laplace_1d(constant=-5, u0=1, u1=2)
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(x,u)
ax.plot(x, u, 'ks')
ax.set_xlim(0,1)
ax.set_xlabel(r'$x$', fontsize=18)
ax.set_ylabel(r'$u(x)$', fontsize=18)
# Out:
# Text(0, 0.5, '$u(x)$')

# %%
N = 100
U = solve_laplace_2d_square(5,-5,3,-1)

x = np.linspace(0, 1, N+2)
X,Y = np.meshgrid(x, x)
fig = plt.figure(figsize=(14, 7))
cmap = matplotlib.cm.get_cmap('RdBu_r')
ax = fig.add_subplot(1,2,1)
c = ax.pcolor(X,Y,U,vmin=-5,vmax=5,cmap=cmap)

ax = fig.add_subplot(1,2,2, projection='3d')
p = ax.plot_surface(X,Y,U,vmin=-5,vmax=5,cmap=cmap)
cb = plt.colorbar(p,ax=ax, shrink=0.75)

# %%
import dolfin
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8284/3394656982.py in <module>
# ----> 1 import dolfin
#
# ModuleNotFoundError: No module named 'dolfin'
